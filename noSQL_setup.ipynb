# %%
# import dependencies

from pymongo import MongoClient
from pprint import pprint
import pandas as pd
mongo = MongoClient(port=27017)

# %% [markdown]
# mongoimport --type csv -d crimes_2021 -c reports --headerline --drop Crime_Incidents_in_2021.csv
#
# mongoimport --type csv -d crimes_2020 -c reports2020 --headerline --drop Crime_Incidents_in_2020.csv
#
# mongoimport --type csv -d election_data -c elections--headerline --drop 'election data.csv'

# %%
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'crimes_2020', 'crimes_2021', 'election_data', 'epa', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
crimes_2021 = mongo['crimes_2021']
crimes_2020 = mongo['crimes_2020']
election_data = mongo['election_data']

# %%
print(crimes_2021.list_collection_names())
print(crimes_2020.list_collection_names())
print(election_data.list_collection_names())
# Out:
# ['reports']
# ['reports2020']
# ['elections']

# %%
pprint(crimes_2021.reports.find_one())
pprint(crimes_2020.reports2020.find_one())
pprint(election_data.elections.find_one())
# Out:
# {'ANC': '5D',
#  'BID': '',
#  'BLOCK': '1800 - 1899 BLOCK OF CENTRAL PLACE NE',
#  'BLOCK_GROUP': '008803 1',
#  'CCN': 12113231,
#  'CENSUS_TRACT': 8803,
#  'DISTRICT': 5,
#  'END_DATE': '2021/08/12 04:00:00+00',
#  'LATITUDE': 38.9125180007,
#  'LONGITUDE': -76.9855987599,
#  'METHOD': 'OTHERS',
#  'NEIGHBORHOOD_CLUSTER': 'Cluster 23',
#  'OBJECTID': 570148270,
#  'OCTO_RECORD_ID': '',
#  'OFFENSE': 'THEFT/OTHER',
#  'PSA': 506,
#  'REPORT_DAT': '2021/08/12 12:00:17+00',
#  'SHIFT': 'DAY',
#  'START_DATE': '2021/08/11 14:30:00+00',
#  'VOTING_PRECINCT': 'Precinct 76',
#  'WARD': 5,
#  'X': -76.98560103973,
#  'XBLOCK': 401249,
#  'Y': 38.912525792004,
#  'YBLOCK': 138295,
#  '_id': ObjectId('66be8a76bc4bcf08083c444c')}
# {'ANC': '2C',
#  'BID': 'GOLDEN TRIANGLE',
#  'BLOCK': '1900 - 1999 BLOCK OF M STREET NW',
#  'BLOCK_GROUP': '010700 1',
#  'CCN': 11139598,
#  'CENSUS_TRACT': 10700,
#  'DISTRICT': 2,
#  'END_DATE': '',
#  'LATITUDE': 38.9056461773,
#  'LONGITUDE': -77.0441795335,
#  'METHOD': 'OTHERS',
#  'NEIGHBORHOOD_CLUSTER': 'Cluster 6',
#  'OBJECTID': 570698887,
#  'OCTO_RECORD_ID': '',
#  'OFFENSE': 'HOMICIDE',
#  'PSA': 207,
#  'REPORT_DAT': '2020/08/24 04:00:00+00',
#  'SHIFT': 'MIDNIGHT',
#  'START_DATE': '2011/09/23 06:40:00+00',
#  'VOTING_PRECINCT': 'Precinct 17',
#  'WARD': 2,
#  'X': -77.0441818311556,
#  'XBLOCK': 396168,
#  'Y': 38.9056539649681,
#  'YBLOCK': 137533,
#  '_id': ObjectId('66be8f29cb2a61528ff245ad')}
# {'ContestName': 'UNITED STATES SENATOR',
#  'ElectionDate': '11/3/2020 0:00',
#  'ElectionName': 'General Election',
#  'Party': 'REP',
#  'PrecinctNumber': 1,
#  'Votes': 411,
#  'WardNumber': 6,
#  '_id': ObjectId('66be8ba64b3f7f587d9d654a')}

# %%
reports2021 = crimes_2021['reports']
crimes2021_df = pd.DataFrame(list(reports2021.find()))
crimes2021_df.head()
# Out:
#                         _id          X          Y       CCN  \
# 0  66be8a76bc4bcf08083c444c -76.985601  38.912526  12113231
# 1  66be8a76bc4bcf08083c444d -77.034107  38.902522  15003190
# 2  66be8a76bc4bcf08083c444e -77.068637  38.932082  11048862
# 3  66be8a76bc4bcf08083c444f -76.997571  38.860774  21182434
# 4  66be8a76bc4bcf08083c4450 -77.012636  38.956595  21182828
#
#                REPORT_DAT     SHIFT  METHOD       OFFENSE  \
# 0  2021/08/12 12:00:17+00       DAY  OTHERS   THEFT/OTHER
# 1  2021/10/21 04:08:27+00  MIDNIGHT  OTHERS  THEFT F/AUTO
# 2  2021/10/13 21:24:42+00   EVENING  OTHERS  THEFT F/AUTO
# 3  2021/12/14 23:15:38+00   EVENING     GUN       ROBBERY
# 4  2021/12/15 18:31:23+00       DAY     GUN       ROBBERY
#
#                                    BLOCK    XBLOCK  ...  BLOCK_GROUP  \
# 0  1800 - 1899 BLOCK OF CENTRAL PLACE NE  401249.0  ...     008803 1
# 1       1434 - 1499 BLOCK OF K STREET NW  397041.7  ...     010100 1
# 2    3100 - 3199 BLOCK OF 35TH STREET NW  394049.0  ...     000600 3
# 3    1100 - 1237 BLOCK OF SUMNER ROAD SE  400211.0  ...     007401 1
# 4  100  - 199 BLOCK OF KENNEDY STREET NW  398905.0  ...     002102 3
#
#   CENSUS_TRACT VOTING_PRECINCT   LATITUDE  LONGITUDE       BID  \
# 0         8803     Precinct 76  38.912518 -76.985599
# 1        10100    Precinct 129  38.902514 -77.034105  DOWNTOWN
# 2          600     Precinct 27  38.932074 -77.068635
# 3         7401    Precinct 119  38.860766 -76.997569
# 4         2102     Precinct 57  38.956587 -77.012633
#
#                START_DATE                END_DATE   OBJECTID  OCTO_RECORD_ID
# 0  2021/08/11 14:30:00+00  2021/08/12 04:00:00+00  570148270
# 1  2021/10/21 00:40:00+00  2021/10/21 02:00:00+00  570148262
# 2  2021/10/13 14:00:00+00  2021/10/13 15:15:00+00  570148266
# 3  2021/12/14 21:46:00+00  2021/12/14 23:00:00+00  570172673
# 4  2021/12/15 17:02:00+00  2021/12/15 17:03:00+00  570172674
#
# [5 rows x 26 columns]

# %%
reports2020 =crimes_2020['reports2020']
crimes2020_df = pd.DataFrame(list(reports2020.find()))
crimes2020_df.head()
# Out:
#                         _id          X          Y       CCN  \
# 0  66be8f29cb2a61528ff245ad -77.044182  38.905654  11139598
# 1  66be8f29cb2a61528ff245ae -77.030788  38.911874     16641
# 2  66be8f29cb2a61528ff245af -76.934386  38.910671  20091820
# 3  66be8f29cb2a61528ff245b0 -76.972651  38.857491  10251445
# 4  66be8f29cb2a61528ff245b1 -77.001753  38.821632  18048023
#
#                REPORT_DAT     SHIFT  METHOD              OFFENSE  \
# 0  2020/08/24 04:00:00+00  MIDNIGHT  OTHERS             HOMICIDE
# 1  2020/01/28 05:14:39+00  MIDNIGHT  OTHERS         THEFT F/AUTO
# 2  2020/06/23 15:57:48+00       DAY  OTHERS  MOTOR VEHICLE THEFT
# 3  2020/09/11 04:00:00+00  MIDNIGHT     GUN             HOMICIDE
# 4  2020/10/21 04:00:00+00  MIDNIGHT  OTHERS             HOMICIDE
#
#                                        BLOCK    XBLOCK  ...  BLOCK_GROUP  \
# 0           1900 - 1999 BLOCK OF M STREET NW  396168.0  ...     010700 1
# 1    1300 - 1399 BLOCK OF CORCORAN STREET NW  397330.0  ...     005001 2
# 2     4600 - 4699 BLOCK OF QUARLES STREET NE  405691.0  ...     009601 1
# 3       2300 - 2399 BLOCK OF AINGER PLACE SE  402374.0  ...     007502 1
# 4  4600 - 4799 BLOCK OF SOUTH CAPITOL STREET  399848.0  ...     009811 1
#
#    CENSUS_TRACT VOTING_PRECINCT   LATITUDE  LONGITUDE              BID  \
# 0         10700     Precinct 17  38.905646 -77.044180  GOLDEN TRIANGLE
# 1          5001     Precinct 16  38.911866 -77.030785
# 2          9601     Precinct 92  38.910663 -76.934383
# 3          7502    Precinct 134  38.857483 -76.972648
# 4          9811    Precinct 125  38.821624 -77.001750
#
#                START_DATE                END_DATE   OBJECTID  OCTO_RECORD_ID
# 0  2011/09/23 06:40:00+00                          570698887
# 1  2020/01/28 05:14:58+00  2020/01/28 05:15:02+00  570699000
# 2  2020/06/18 13:00:12+00  2020/06/22 14:00:15+00  570722713
# 3  2010/09/02 04:00:00+00  2010/09/02 04:00:00+00  570698997
# 4  2018/03/26 08:40:06+00  2018/03/26 10:04:44+00  570700076
#
# [5 rows x 26 columns]

# %%
election = election_data['elections']
election_df = pd.DataFrame(list(election.find()))
election_df.head()
# Out:
#                         _id    ElectionDate      ElectionName  \
# 0  66be8ba64b3f7f587d9d654a  11/3/2020 0:00  General Election
# 1  66be8ba64b3f7f587d9d654b  11/3/2020 0:00  General Election
# 2  66be8ba64b3f7f587d9d654c  11/3/2020 0:00  General Election
# 3  66be8ba64b3f7f587d9d654d  11/3/2020 0:00  General Election
# 4  66be8ba64b3f7f587d9d654e  11/3/2020 0:00  General Election
#
#                                          ContestName  PrecinctNumber  \
# 0                              UNITED STATES SENATOR               1
# 1                              UNITED STATES SENATOR               3
# 2  ELECTORS OF PRESIDENT AND VICE PRESIDENT OF TH...               4
# 3                     AT-LARGE MEMBER OF THE COUNCIL               4
# 4                              UNITED STATES SENATOR               4
#
#    WardNumber Party  Votes
# 0           6   REP    411
# 1           2   REP    257
# 2           2   REP    267
# 3           2   REP    290
# 4           2   REP    353
